# %%
import sys
import numpy as np
import seaborn as sns
import matplotlib
# matplotlib.use('Agg')
import matplotlib.pyplot as plt


# лучше прописать пути

ROOT_DIR = r'C:\Users\user\Desktop\test_project\test_project'

sys.path.insert(1, r'C:\Users\user\Desktop\test_project')

# %%
from test_project.utils import Data, Plots
from test_project.config import csv_path, json_path, url_path

# %%
df = Data.read_csv(path=csv_path).df
# df = Data.read_json(path=json_path)  # from json file
# df = Data.read_json_url(path=url_path)  from json by url

# %%
df
# Out:
#                   name  gt_corners  rb_corners       mean        max  \
# 0         Schlafzimmer         4.0         4.0   3.956313   8.562939
# 1                Küche         4.0         4.0  23.019122  52.605437
# 2             Bathroom         4.0         4.0   1.013833   1.950322
# 3         Lounge/Diner         8.0         8.0   3.832620  18.236935
# 4           Essbereich         4.0         4.0   8.017758  15.642853
# ...                ...         ...         ...        ...        ...
# 1342    Master Bedroom         4.0         4.0   1.739907   4.703960
# 1343  Master Bedroom 2         4.0         4.0   0.530908   0.786997
# 1344          Zimmer I         4.0         4.0   0.880569   1.221873
# 1345  Hallway Bathroom         6.0         6.0  24.923452  64.266820
# 1346         Bedroom 4         4.0         4.0   0.387328   0.762659
#
#            min  floor_mean  floor_max  floor_min  ceiling_mean  ceiling_max  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1347 entries, 0 to 1346
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          1347 non-null   object
#  1   gt_corners    1347 non-null   float64
#  2   rb_corners    1347 non-null   float64
#  3   mean          1347 non-null   float64
#  4   max           1347 non-null   float64
#  5   min           1347 non-null   float64
#  6   floor_mean    1347 non-null   float64
#  7   floor_max     1347 non-null   float64
#  8   floor_min     1347 non-null   float64
#  9   ceiling_mean  1347 non-null   float64
#  10  ceiling_max   1347 non-null   float64
#  11  ceiling_min   1347 non-null   float64
# dtypes: float64(11), object(1)
# memory usage: 136.8+ KB

# %%
df.describe()
# Out:
#         gt_corners   rb_corners         mean          max          min  \
# count  1347.000000  1347.000000  1347.000000  1347.000000  1347.000000
# mean      4.307350     4.307350    12.895320    25.448011     2.920388
# std       0.814412     0.814412    21.839948    42.758159     9.258972
# min       4.000000     4.000000     0.192973     0.323886     0.007456
# 25%       4.000000     4.000000     0.658488     1.243804     0.147432
# 50%       4.000000     4.000000     2.123456     4.703514     0.279876
# 75%       4.000000     4.000000    14.810982    28.312051     0.674444
# max      10.000000    10.000000   121.301055   179.165483    81.764483
#
#         floor_mean    floor_max    floor_min  ceiling_mean  ceiling_max  \
# count  1347.000000  1347.000000  1347.000000   1347.000000  1347.000000
# mean     11.022443    20.405499     3.146246     14.768198    24.848020
# std      19.136320    33.189081     9.559611     26.047057    42.345579
# ...

# %%
df.isna().sum()  # there is no nan values
# Out:
# name            0
# gt_corners      0
# rb_corners      0
# mean            0
# max             0
# min             0
# floor_mean      0
# floor_max       0
# floor_min       0
# ceiling_mean    0
# ceiling_max     0
# ceiling_min     0
# dtype: int64

# %%
df.nunique()
# Out:
# name             588
# gt_corners         4
# rb_corners         4
# mean            1347
# max             1347
# min             1347
# floor_mean      1347
# floor_max       1347
# floor_min       1347
# ceiling_mean    1347
# ceiling_max     1347
# ceiling_min     1347
# dtype: int64

# %%
# plots object

plots = Plots(df)

# %%
# plot any number and combination of columns

plots.plot_columns(columns=df.columns[:4], type_='scatter')  # or plot

# %%
# correlations

plots.plot_corr_heatmap()

# %%
# pairplot

# plots.plot_pairplot()

# %%
# count unique values for any column

plots.plot_unique(column='gt_corners')

# %%
# count mean mean value for different gt_corners group
# we can take any column as unique group generator
# any column to calculate metrics
# any metric from numpy module (mean, sum, min, max, std, etc)

plots.count_compare_unique(unique_column='gt_corners', compare_column='mean', compare_type='mean')

# %%
# boxplot for any column groups by any column value

plots.boxplot(unique_column='gt_corners', count_column='mean')

# %%
columns = df.columns[1:]

image_fns = []
for column in columns:
    for type_ in ['plot', 'scatter']:
        fn = f'{ROOT_DIR}/charts/columns_charts/{column}_{type_}_plot'
        image_fns.append(plots.plot_columns([column], type_=type_, save_fn=fn, show=False))
# Out:
# C:\Users\user\Desktop\test_project\test_project\utils.py:41: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=def_figsize)

# %%
image_fns
# Out:
# ['C:\\Users\\user\\Desktop\\test_project\\test_project/charts/columns_charts/gt_corners_plot_plot',
#  'C:\\Users\\user\\Desktop\\test_project\\test_project/charts/columns_charts/gt_corners_scatter_plot',
#  'C:\\Users\\user\\Desktop\\test_project\\test_project/charts/columns_charts/rb_corners_plot_plot',
#  'C:\\Users\\user\\Desktop\\test_project\\test_project/charts/columns_charts/rb_corners_scatter_plot',
#  'C:\\Users\\user\\Desktop\\test_project\\test_project/charts/columns_charts/mean_plot_plot',
#  'C:\\Users\\user\\Desktop\\test_project\\test_project/charts/columns_charts/mean_scatter_plot',
#  'C:\\Users\\user\\Desktop\\test_project\\test_project/charts/columns_charts/max_plot_plot',
#  'C:\\Users\\user\\Desktop\\test_project\\test_project/charts/columns_charts/max_scatter_plot',
#  'C:\\Users\\user\\Desktop\\test_project\\test_project/charts/columns_charts/min_plot_plot',
#  'C:\\Users\\user\\Desktop\\test_project\\test_project/charts/columns_charts/min_scatter_plot',
# ...
